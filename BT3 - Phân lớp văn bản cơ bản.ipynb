# %% [markdown]
#  BÀI 1.

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
import pandas as pd
X_train = pd.read_csv('/content/drive/MyDrive/ UIT-VSFC/train/sents.txt', sep='\n', header=None, index_col=None)
y_train = pd.read_csv('/content/drive/MyDrive/ UIT-VSFC/train/sentiments.txt', sep='\n', header=None, index_col=None)
X_dev = pd.read_csv('/content/drive/MyDrive/ UIT-VSFC/dev/sents.txt', sep='\n', header=None, index_col=None)
y_dev = pd.read_csv('/content/drive/MyDrive/ UIT-VSFC/dev/sentiments.txt', sep='\n', header=None, index_col=None)
X_test = pd.read_csv('/content/drive/MyDrive/ UIT-VSFC/test/sents.txt', sep='\n', header=None, index_col=None)
y_test = pd.read_csv('/content/drive/MyDrive/ UIT-VSFC/test/sentiments.txt', sep='\n', header=None, index_col=None)
y_train = y_train.values.flatten()
y_dev = y_dev.values.flatten()
y_test = y_test.values.flatten()

# %%
from sklearn.feature_extraction.text import CountVectorizer
encoder = CountVectorizer(ngram_range=(2, 2))
encoder.fit(X_train[0])
encoder.vocabulary_
X_train_encoded = encoder.transform(X_train[0])
X_dev_encoded = encoder.transform(X_dev[0])
X_test_encoded = encoder.transform(X_test[0])

from sklearn.naive_bayes import MultinomialNB
model = MultinomialNB()
model.fit(X_train_encoded, y_train)

y_pred = model.predict(X_test_encoded)

from sklearn.metrics import accuracy_score, f1_score
print(accuracy_score(y_test, y_pred)*100)
print(f1_score(y_test, y_pred, average='macro')*100)
# Out:
# 86.26026531901452
# 61.264058918064244

# %%
from sklearn.metrics import confusion_matrix
cf = confusion_matrix(y_test, y_pred)
import seaborn as sn
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
df_cm = pd.DataFrame(cf, range(3), range(3))
sn.set(font_scale=1.4) 
sn.heatmap(df_cm, annot=True, annot_kws={"size": 16}, fmt='d') 
plt.show()

# %% [markdown]
# BÀI 2.

# %%
from sklearn.feature_extraction.text import TfidfVectorizer
encoder = TfidfVectorizer(ngram_range=(2, 2))
encoder.fit(X_train[0])
encoder.vocabulary_
X_train_encoded = encoder.transform(X_train[0])
X_dev_encoded = encoder.transform(X_dev[0])
X_test_encoded = encoder.transform(X_test[0])

from sklearn.metrics import accuracy_score, f1_score
from sklearn.naive_bayes import MultinomialNB
model = MultinomialNB()
model.fit(X_train_encoded, y_train)
y_pred = model.predict(X_test_encoded)

print(accuracy_score(y_test, y_pred)*100)
print(f1_score(y_test, y_pred, average='macro')*100)
# Out:
# 86.35502210991788
# 59.09980504824439

# %% [markdown]
# BÀI 3

# %%
from sklearn.feature_extraction.text import CountVectorizer
encoder = CountVectorizer(ngram_range=(2, 2))
encoder.fit(X_train[0])
encoder.vocabulary_
X_train_encoded = encoder.transform(X_train[0])
X_dev_encoded = encoder.transform(X_dev[0])
X_test_encoded = encoder.transform(X_test[0])
print("CountVectorizer")

from sklearn.naive_bayes import MultinomialNB
model_NB = MultinomialNB()
model_NB.fit(X_train_encoded, y_train)
y_pred_NB = model_NB.predict(X_test_encoded)
print("Naive Bayes")
print(accuracy_score(y_test, y_pred_NB)*100)
print(f1_score(y_test, y_pred_NB, average='macro')*100)

from sklearn.linear_model import LogisticRegression
model_LR = LogisticRegression()
model_LR.fit(X_train_encoded, y_train)
y_pred_LR = model_LR.predict(X_test_encoded)
print("")
print("LogicsticRegression")
print(accuracy_score(y_test, y_pred_LR)*100)
print(f1_score(y_test, y_pred_LR, average='macro')*100)

from sklearn.svm import LinearSVC
model_SVM = LinearSVC()
model_SVM.fit(X_train_encoded, y_train)
y_pred_SVM = model_SVM.predict(X_test_encoded)
print("")
print("SVM")
print(accuracy_score(y_test, y_pred_SVM)*100)
print(f1_score(y_test, y_pred_SVM, average='macro')*100)
# Out:
# CountVectorizer
# Naive Bayes
# 86.26026531901452
# 61.264058918064244
#
# LogicsticRegression
# 87.08149084017688
# 65.45099659996735
#
# SVM
# 86.38660770688567
# 69.25005831414651

# %%
from sklearn.feature_extraction.text import TfidfVectorizer
encoder = TfidfVectorizer(ngram_range=(2, 2))
encoder.fit(X_train[0])
encoder.vocabulary_
X_train_encoded = encoder.transform(X_train[0])
X_dev_encoded = encoder.transform(X_dev[0])
X_test_encoded = encoder.transform(X_test[0])

print("TfidfVectorizer")

from sklearn.naive_bayes import MultinomialNB
model_NB = MultinomialNB()
model_NB.fit(X_train_encoded, y_train)
y_pred_NB = model_NB.predict(X_test_encoded)
print("Naive Bayes")
print(accuracy_score(y_test, y_pred_NB)*100)
print(f1_score(y_test, y_pred_NB, average='macro')*100)

from sklearn.linear_model import LogisticRegression
model_LR = LogisticRegression()
model_LR.fit(X_train_encoded, y_train)
y_pred_LR = model_LR.predict(X_test_encoded)
print("")
print("LogicsticRegression")
print(accuracy_score(y_test, y_pred_LR)*100)
print(f1_score(y_test, y_pred_LR, average='macro')*100)

from sklearn.svm import LinearSVC
model_SVM = LinearSVC()
model_SVM.fit(X_train_encoded, y_train)
y_pred_SVM = model_SVM.predict(X_test_encoded)
print("")
print("SVM")
print(accuracy_score(y_test, y_pred_SVM)*100)
print(f1_score(y_test, y_pred_SVM, average='macro')*100)
# Out:
# TfidfVectorizer
# Naive Bayes
# 86.35502210991788
# 59.09980504824439
#
# LogicsticRegression
# 86.29185091598231
# 62.33059320033595
#
# SVM
# 87.80795957043588
# 67.38105147438263
# /usr/local/lib/python3.7/dist-packages/sklearn/linear_model/_logistic.py:818: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   extra_warning_msg=_LOGISTIC_SOLVER_CONVERGENCE_MSG,

# %% [markdown]
# Với phương pháp TfidfVectorizer thì mô hình SVM cho kết quả tốt nhất.

# %% [markdown]
# Với phương pháp CountVectorizer thì mô hình LogicsticRegression cho kết quả tốt nhất

# %% [markdown]
# Phân tích lỗi

# %%
confusion_matrix(y_test, y_pred_LR)
# Out:
# array([[1343,    2,   64],
#        [ 111,    9,   47],
#        [ 206,    4, 1380]])

# %%
confusion_matrix(y_test, y_pred_NB)
# Out:
# array([[1290,    0,  119],
#        [  98,    0,   69],
#        [ 146,    0, 1444]])

# %%
confusion_matrix(y_test, y_pred_SVM)
# Out:
# array([[1326,    7,   76],
#        [  93,   23,   51],
#        [ 148,   11, 1431]])

# %%
from pandas._libs.hashtable import value_count
y_train = pd.DataFrame(y_train)
import seaborn as sns
sns.barplot(
    x = [0,1,2],
    y = [y_train.value_counts()[0,],y_train.value_counts()[1,],y_train.value_counts()[2,]]
)

# %% [markdown]
# Dữ liệu về y_train có giá trị bằng 1 ít hơn nhiều so với dữ liệu về 0 và 2 -> chênh lệch dữ liệu -> khả năng dự đoán giảm.
